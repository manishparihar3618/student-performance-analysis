# %%
import sys
import os
sys.path.append(os.path.abspath("src"))
from data_cleaning import clean_data
df = clean_data()
df['Total_Marks']=df[['Math','Science','English']].sum(axis=1)
df
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[26], line 4
#       2 import os
#       3 sys.path.append(os.path.abspath("src"))
# ----> 4 from data_cleaning import clean_data
#       5 df = clean_data()
#       6 df['Total_Marks']=df[['Math','Science','English']].sum(axis=1)
#
# ImportError: cannot import name 'clean_data' from 'data_cleaning' (c:\Users\Manis\OneDrive\vs COdE Python\student-performance-analyzer\student-performance-analysis\src\data_cleaning.py)
