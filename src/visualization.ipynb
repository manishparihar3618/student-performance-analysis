# %%
import matplotlib.pyplot as plt
import seaborn as sns 
import sys, os
sys.path.append(os.path.abspath('src'))

# %%
from feature_engineering import get_feature_engg_data

df= get_feature_engg_data
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 from feature_engineering import get_feature_engg_data
#       3 df= get_feature_engg_data
#
# ImportError: cannot import name 'get_feature_engg_data' from 'feature_engineering' (c:\Users\Manis\OneDrive\vs COdE Python\student-performance-analyzer\student-performance-analysis\src\feature_engineering.py)
